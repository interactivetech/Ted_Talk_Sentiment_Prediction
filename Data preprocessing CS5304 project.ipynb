# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
a = pd.read_csv("data/transcripts.csv")

# %%
# a["url"]

# %%
a["transcript"].apply(lambda x: len(x.split(" "))).describe()
# Out:
# count    2467.000000
# mean     2041.959465
# std       956.478815
# min         1.000000
# 25%      1336.000000
# 50%      2029.000000
# 75%      2707.500000
# max      9044.000000
# Name: transcript, dtype: float64

# %% [markdown]
# 1. Average number of words in ted talk: 2000 words
# 2. Max TED Talk has 9000 words in it

# %%
import textacy

# %% [markdown]
# ### Clean up text to only include unicode, and convert to textacy document

# %%
ex = textacy.Doc(content=a["transcript"][0].decode('utf-8'),lang=u'en')

# %%
from textacy.keyterms import sgrank

# %% [markdown]
# ### Get Topics of a Document

# %%
textrank(ex,n_keyterms=10)
# Out:
# [(u'education', 0.018482597870771732),
#  (u'thing', 0.015298506952932835),
#  (u'people', 0.014231480092299567),
#  (u'way', 0.011517267298331973),
#  (u'kid', 0.010263765982329335),
#  (u'child', 0.00890355757567635),
#  (u'year', 0.008815724232791696),
#  (u'school', 0.008628570304400627),
#  (u'human', 0.008134166700086131),
#  (u'what', 0.008100449128440587)]

# %% [markdown]
# ## Create list of textacy Documents that will be used to create BOW Matrix

# %%
corpus=[]
docs = a['transcript'].tolist()[:200]
for doc in tqdm(docs):
    corpus.append(textacy.Doc(content=doc.decode('utf-8'),lang=u'en'))
# Out:
# 100%|██████████| 200/200 [02:20<00:00,  1.43it/s]

# %%
tokenized_docs = (doc.to_terms_list(ngrams=1, named_entities=True, as_strings=True) for doc in corpus)
vectorizer = textacy.Vectorizer(apply_idf=True, norm='l2',min_df=3, max_df=0.95)
doc_term_matrix = vectorizer.fit_transform(tokenized_docs)
doc_term_matrix
# Out:
# <200x6241 sparse matrix of type '<type 'numpy.float64'>'
# 	with 90633 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Get Labels

# %%
metadata = pd.read_csv("data/ted_main.csv")

# %%
import json

# %%
# help(json.loads)

# %%
json.loads("{\"a\":1}")
# Out:
# {u'a': 1}

# %% [markdown]
# json uses " as a formatting character, Json escapes quotes inside strings as \" so replace ' with "

# %%
arr = json.loads(metadata['ratings'][0].replace("'",'\"'))

# %% [markdown]
# Want to be in one dictionary so I can sort and retrieve best rating

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module __builtin__:
#
# sorted(...)
#     sorted(iterable, cmp=None, key=None, reverse=False) --> new sorted list

# %%
def combine_list_of_dicts(arr):
    dict_ratings = {}
    for a in arr:
        if a["id"] not in dict_ratings:
            dict_ratings[a["id"]]=a
            
    return dict_ratings

d = combine_list_of_dicts(arr)

# %%
sorted(d.items(), key= lambda x:x[1]["count"],reverse=True)
# Out:
# [(10, {u'count': 24924, u'id': 10, u'name': u'Inspiring'}),
#  (7, {u'count': 19645, u'id': 7, u'name': u'Funny'}),
#  (24, {u'count': 10704, u'id': 24, u'name': u'Persuasive'}),
#  (22, {u'count': 10581, u'id': 22, u'name': u'Fascinating'}),
#  (8, {u'count': 7346, u'id': 8, u'name': u'Informative'}),
#  (9, {u'count': 6073, u'id': 9, u'name': u'Ingenious'}),
#  (1, {u'count': 4573, u'id': 1, u'name': u'Beautiful'}),
#  (23, {u'count': 4439, u'id': 23, u'name': u'Jaw-dropping'}),
#  (3, {u'count': 3253, u'id': 3, u'name': u'Courageous'}),
#  (25, {u'count': 1174, u'id': 25, u'name': u'OK'}),
#  (11, {u'count': 387, u'id': 11, u'name': u'Longwinded'}),
#  (21, {u'count': 300, u'id': 21, u'name': u'Unconvincing'}),
#  (2, {u'count': 242, u'id': 2, u'name': u'Confusing'}),
#  (26, {u'count': 209, u'id': 26, u'name': u'Obnoxious'})]

# %% [markdown]
# ## sort ratings by highest count,use first one as highest rating
#
# Note: May have bias that TED Talks are more inclined to be inspiring

# %%
def getTEDRating(string):
    arr = json.loads(string.replace("'",'\"'))
    d = combine_list_of_dicts(arr) 
#     print(d.items())
    return sorted(d.items(), key= lambda x:x[1]["count"],reverse=True)[0][1]['id']
getTEDRating(metadata['ratings'][0])
# Out:
# 10

# %% [markdown]
# # Create array of labels, where the label is the highest rating for that TED Talk

# %%
labels = [getTEDRating(x) for x in metadata['ratings'].tolist()]

# %%
labels
# Out:
# [10,
#  7,
#  7,
#  10,
#  8,
#  10,
#  7,
#  9,
#  24,
#  10,
#  10,
#  10,
#  10,
#  23,
#  10,
#  23,
#  23,
#  10,
#  10,
#  8,
#  8,
#  7,
#  11,
#  8,
#  10,
#  24,
#  22,
#  8,
#  22,
#  22,
#  8,
#  10,
#  24,
#  10,
#  10,
#  8,
#  8,
#  10,
#  10,
#  10,
#  8,
#  9,
#  8,
#  7,
#  8,
#  24,
#  10,
#  10,
#  7,
#  8,
#  8,
#  24,
#  10,
#  10,
#  22,
#  10,
#  8,
#  10,
#  23,
#  22,
#  8,
#  10,
#  10,
#  10,
#  10,
#  3,
#  10,
#  10,
#  8,
#  22,
#  9,
#  8,
#  10,
#  10,
#  10,
#  10,
#  1,
#  10,
#  7,
#  21,
#  10,
#  8,
#  1,
#  23,
#  1,
#  22,
#  7,
#  1,
#  8,
#  10,
#  24,
#  8,
#  1,
#  1,
#  1,
#  3,
#  3,
#  7,
#  1,
#  8,
#  1,
#  8,
#  7,
#  24,
#  10,
#  21,
#  22,
#  8,
#  23,
#  10,
#  10,
#  9,
#  10,
#  11,
#  24,
#  1,
#  23,
#  23,
#  23,
#  24,
#  22,
#  23,
#  8,
#  23,
#  7,
#  23,
#  7,
#  10,
#  24,
#  10,
#  10,
#  10,
#  1,
#  10,
#  1,
#  1,
#  10,
#  23,
#  7,
#  24,
#  23,
#  8,
#  24,
#  3,
#  8,
#  7,
#  8,
#  9,
#  23,
#  23,
#  10,
#  22,
#  7,
#  8,
#  22,
#  8,
#  3,
#  10,
#  24,
#  22,
#  24,
#  24,
#  10,
#  22,
#  22,
#  7,
#  8,
#  8,
#  23,
#  10,
#  1,
#  24,
#  10,
#  7,
#  22,
#  7,
#  22,
#  8,
#  11,
#  1,
#  10,
#  10,
#  7,
#  7,
#  10,
#  8,
#  10,
#  1,
#  10,
#  10,
#  1,
#  22,
#  10,
#  7,
#  7,
#  10,
#  22,
#  22,
#  10,
#  23,
#  22,
#  10,
#  11,
#  10,
#  10,
#  10,
#  10,
#  22,
#  7,
#  1,
#  22,
#  8,
#  21,
#  22,
#  10,
#  9,
#  10,
#  8,
#  10,
#  10,
#  22,
#  22,
#  7,
#  10,
#  22,
#  8,
#  22,
#  22,
#  8,
#  8,
#  22,
#  10,
#  1,
#  10,
#  24,
#  22,
#  7,
#  1,
#  22,
#  25,
#  8,
#  10,
#  8,
#  22,
#  9,
#  8,
#  10,
#  10,
#  7,
#  26,
#  10,
#  1,
#  1,
#  3,
#  22,
#  10,
#  8,
#  7,
#  22,
#  8,
#  10,
#  7,
#  23,
#  10,
#  1,
#  10,
#  8,
#  10,
#  8,
#  22,
#  8,
#  22,
#  25,
#  8,
#  22,
#  1,
#  23,
#  8,
#  1,
#  22,
#  10,
#  10,
#  7,
#  22,
#  10,
#  8,
#  8,
#  10,
#  8,
#  8,
#  22,
#  7,
#  8,
#  8,
#  8,
#  10,
#  8,
#  2,
#  10,
#  10,
#  9,
#  8,
#  8,
#  10,
#  21,
#  22,
#  8,
#  22,
#  10,
#  8,
#  23,
#  22,
#  22,
#  8,
#  8,
#  7,
#  22,
#  10,
#  3,
#  8,
#  7,
#  22,
#  3,
#  10,
#  10,
#  10,
#  10,
#  10,
#  8,
#  22,
#  8,
#  10,
#  10,
#  22,
#  8,
#  10,
#  22,
#  7,
#  11,
#  7,
#  10,
#  22,
#  8,
#  10,
#  7,
#  8,
#  22,
#  8,
#  21,
#  9,
#  1,
#  10,
#  8,
#  22,
#  8,
#  8,
#  8,
#  22,
#  10,
#  7,
#  7,
#  11,
#  8,
#  21,
#  8,
#  10,
#  22,
#  8,
#  8,
#  10,
#  7,
#  8,
#  8,
#  10,
#  9,
#  8,
#  10,
#  9,
#  1,
#  9,
#  10,
#  10,
#  10,
#  9,
#  10,
#  22,
#  10,
#  1,
#  10,
#  10,
#  23,
#  8,
#  22,
#  1,
#  8,
#  8,
#  10,
#  10,
#  10,
#  23,
#  7,
#  23,
#  10,
#  22,
#  8,
#  7,
#  22,
#  7,
#  7,
#  8,
#  9,
#  10,
#  7,
#  10,
#  8,
#  1,
#  10,
#  23,
#  8,
#  8,
#  1,
#  8,
#  22,
#  7,
#  7,
#  24,
#  10,
#  22,
#  10,
#  10,
#  22,
#  11,
#  8,
#  8,
#  11,
#  10,
#  8,
#  7,
#  8,
#  8,
#  8,
#  10,
#  1,
#  8,
#  21,
#  10,
#  1,
#  8,
#  8,
#  23,
#  10,
#  22,
#  7,
#  22,
#  25,
#  7,
#  8,
#  10,
#  8,
#  1,
#  10,
#  8,
#  10,
#  1,
#  21,
#  9,
#  10,
#  8,
#  22,
#  10,
#  22,
#  8,
#  21,
#  22,
#  23,
#  8,
#  24,
#  10,
#  10,
#  24,
#  10,
#  26,
#  2,
#  8,
#  3,
#  9,
#  8,
#  10,
#  9,
#  8,
#  8,
#  10,
#  10,
#  7,
#  21,
#  23,
#  9,
#  24,
#  10,
#  10,
#  10,
#  9,
#  8,
#  10,
#  8,
#  9,
#  10,
#  22,
#  3,
#  24,
#  3,
#  22,
#  1,
#  8,
#  10,
#  7,
#  22,
#  1,
#  10,
#  8,
#  10,
#  22,
#  10,
#  8,
#  10,
#  10,
#  22,
#  10,
#  8,
#  10,
#  10,
#  22,
#  7,
#  22,
#  22,
#  7,
#  22,
#  8,
#  8,
#  22,
#  10,
#  9,
#  8,
#  24,
#  9,
#  10,
#  22,
#  25,
#  8,
#  8,
#  8,
#  8,
#  8,
#  23,
#  9,
#  10,
#  10,
#  8,
#  22,
#  10,
#  9,
#  10,
#  10,
#  10,
#  8,
#  10,
#  8,
#  3,
#  7,
#  10,
#  10,
#  8,
#  8,
#  10,
#  7,
#  22,
#  8,
#  3,
#  8,
#  10,
#  22,
#  10,
#  10,
#  22,
#  1,
#  8,
#  8,
#  1,
#  10,
#  22,
#  10,
#  10,
#  10,
#  8,
#  8,
#  7,
#  22,
#  1,
#  22,
#  23,
#  8,
#  10,
#  8,
#  9,
#  10,
#  9,
#  7,
#  10,
#  8,
#  10,
#  9,
#  8,
#  1,
#  3,
#  10,
#  23,
#  10,
#  10,
#  8,
#  22,
#  24,
#  8,
#  10,
#  10,
#  10,
#  22,
#  22,
#  22,
#  9,
#  22,
#  10,
#  23,
#  10,
#  10,
#  9,
#  10,
#  7,
#  10,
#  23,
#  24,
#  7,
#  10,
#  10,
#  10,
#  24,
#  8,
#  24,
#  22,
#  10,
#  10,
#  10,
#  10,
#  8,
#  10,
#  10,
#  7,
#  24,
#  10,
#  9,
#  8,
#  1,
#  24,
#  10,
#  8,
#  10,
#  1,
#  22,
#  7,
#  9,
#  10,
#  8,
#  10,
#  22,
#  10,
#  8,
#  7,
#  24,
#  10,
#  24,
#  10,
#  1,
#  8,
#  9,
#  24,
#  10,
#  7,
#  10,
#  8,
#  24,
#  8,
#  21,
#  23,
#  10,
#  8,
#  8,
#  8,
#  1,
#  24,
#  23,
#  10,
#  7,
#  10,
#  9,
#  24,
#  10,
#  7,
#  8,
#  22,
#  8,
#  8,
#  8,
#  10,
#  10,
#  10,
#  10,
#  10,
#  8,
#  7,
#  10,
#  8,
#  8,
#  1,
#  9,
#  22,
#  8,
#  10,
#  8,
#  24,
#  22,
#  10,
#  10,
#  3,
#  10,
#  22,
#  23,
#  8,
#  8,
#  8,
#  10,
#  22,
#  22,
#  10,
#  24,
#  10,
#  24,
#  22,
#  7,
#  7,
#  22,
#  22,
#  8,
#  10,
#  10,
#  8,
#  8,
#  10,
#  8,
#  10,
#  8,
#  22,
#  10,
#  22,
#  10,
#  10,
#  7,
#  8,
#  10,
#  8,
#  8,
#  1,
#  8,
#  10,
#  10,
#  10,
#  9,
#  8,
#  8,
#  8,
#  22,
#  10,
#  7,
#  9,
#  10,
#  8,
#  8,
#  10,
#  22,
#  10,
#  8,
#  9,
#  10,
#  3,
#  10,
#  8,
#  8,
#  7,
#  1,
#  10,
#  8,
#  24,
#  8,
#  1,
#  8,
#  9,
#  10,
#  22,
#  1,
#  10,
#  8,
#  3,
#  24,
#  8,
#  24,
#  22,
#  10,
#  10,
#  8,
#  26,
#  10,
#  10,
#  10,
#  10,
#  10,
#  24,
#  9,
#  10,
#  10,
#  10,
#  10,
#  8,
#  10,
#  7,
#  10,
#  10,
#  1,
#  10,
#  10,
#  10,
#  10,
#  7,
#  8,
#  22,
#  8,
#  10,
#  10,
#  22,
#  7,
#  10,
#  8,
#  24,
#  10,
#  10,
#  22,
#  7,
#  8,
#  24,
#  7,
#  21,
#  10,
#  9,
#  10,
#  8,
#  10,
#  1,
#  10,
#  22,
#  10,
#  10,
#  1,
#  10,
#  22,
#  10,
#  8,
#  10,
#  24,
#  8,
#  10,
#  8,
#  1,
#  10,
#  10,
#  10,
#  8,
#  23,
#  10,
#  10,
#  22,
#  8,
#  10,
#  22,
#  10,
#  1,
#  10,
#  7,
#  7,
#  23,
#  10,
#  1,
#  10,
#  8,
#  9,
#  10,
#  1,
#  9,
#  10,
#  10,
#  7,
#  10,
#  10,
#  1,
#  22,
#  10,
#  10,
#  10,
#  10,
#  24,
#  10,
#  10,
#  22,
#  10,
#  22,
#  8,
#  9,
#  9,
#  10,
#  8,
#  10,
#  9,
#  9,
#  22,
#  1,
#  1,
#  9,
#  10,
#  9,
#  10,
#  22,
#  10,
#  8,
#  22,
#  7,
#  7,
#  22,
#  10,
#  10,
#  8,
#  1,
#  10,
#  10,
#  25,
#  22,
#  10,
#  10,
#  22,
#  1,
#  8,
#  8,
#  3,
#  22,
#  7,
#  10,
#  1,
#  9,
#  1,
#  8,
#  22,
#  1,
#  22,
#  3,
#  10,
#  22,
#  10,
#  1,
#  10,
#  8,
#  1,
#  10,
#  8,
#  8,
#  24,
#  10,
#  10,
#  8,
#  10,
#  22,
#  23,
#  24,
#  22,
#  22,
#  10,
#  10,
#  22,
#  9,
#  8,
#  8,
#  8,
#  10,
#  10,
#  10,
#  10,
#  ...]

# %%
a['transcript']
# Out:
# 0       Good morning. How are you?(Laughter)It's been ...
# 1       Thank you so much, Chris. And it's truly a gre...
# 2       (Music: "The Sound of Silence," Simon & Garfun...
# 3       If you're here today — and I'm very happy that...
# 4       About 10 years ago, I took on the task to teac...
# 5       Thank you. I have to tell you I'm both challen...
# 6       On September 10, the morning of my seventh bir...
# 7       I'm going to present three projects in rapid f...
# 8       It's wonderful to be back. I love this wonderf...
# 9       I'm often asked, "What surprised you about the...
# 10      I'm going to take you on a journey very quickl...
# 11      I can't help but this wish: to think about whe...
# 12      I'm the luckiest guy in the world. I got to se...
# 13      I'm really excited to be here today. I'll show...
# 14      I've been at MIT for 44 years. I went to TED I...
# 15      (Music)(Music ends)(Applause)(Applause ends)Hi...
# 16      (Music)(Music ends)(Applause)Thank you!(Applau...
# 17      In terms of invention, I'd like to tell you th...
# 18      My name is Lovegrove. I only know nine Lovegro...
# 19      Charles Van Doren, who was later a senior edit...
# 20      I'm Rich Baraniuk and what I'd like to talk a ...
# 21      You know, when Chris first approached me to sp...
# 22      Over the past couple of days, as I've been pre...
# 23      I'd like to talk today about the two biggest s...
# 24      I bet you're worried.(Laughter)I was worried. ...
# 25      We've been told to go out on a limb and say so...
# 26      My title: "Queerer than we can suppose: the st...
# 27      You'll be happy to know that I'll be talking n...
# 28      I think I was supposed to talk about my new bo...
# 29      When you have 21 minutes to speak, two million...
#                               ...
# 2437    Someday, we may have robots as smart as people...
# 2438    This is a talk about sugar and cancer. I becam...
# 2439    [Yoruba: Freeborn Ijebu-Ode son,] [of true Ogb...
# 2440    Are you tired of your boss?(Laughter)Are you t...
# 2441    So, my mother's a pediatrician, and when I was...
# 2442    These are some photos of me volunteering in a ...
# 2443    Today, I'm going to talk about AI and us. AI r...
# 2444    We are all activists now.(Applause)Thank you.I...
# 2445    Why do people deliberately destroy cultural he...
# 2446    I'm Chetan Bhatt and when I give my name, I'm ...
# 2447    Do you remember these glow-in-the-dark little ...
# 2448    So in 2011, I altered my name so that I could ...
# 2449    Whether you like it or not, radical transparen...
# 2450    This is my favorite place on earth, Salar de U...
# 2451    It's Christmas Eve, 1968. The Apollo 8 spacecr...
# 2452    Cities are like siblings in a large polygamous...
# 2453    Caitlin Quattromani: The election of 2016 felt...
# 2454    I used to think the whole purpose of life was ...
# 2455    How many companies have you interacted with to...
# 2456    I was born and raised in Dakar, Senegal, and t...
# 2457    When someone mentions Cuba, what do you think ...
# 2458    As you heard, I'm a physicist. And I think the...
# 2459    I'd like for you to take a moment to imagine t...
# 2460    Today I'm here, actually, to pose you a questi...
# 2461    What stands between Africa's current prostrate...
# 2462    So, Ma was trying to explain something to me a...
# 2463    This is a picture of a sunset on Mars taken by...
# 2464    In my early days as a graduate student, I went...
# 2465    I took a cell phone and accidentally made myse...
# 2466    We humans are becoming an urban species, so ci...
# Name: transcript, Length: 2467, dtype: object

# %%
seriess = {'transcripts': pd.Series(a['transcript']),
    'labels': pd.Series(labels)}
dataset = pd.DataFrame(seriess)

# %%
dataset
# Out:
#       labels                                        transcripts
# 0         10  Good morning. How are you?(Laughter)It's been ...
# 1          7  Thank you so much, Chris. And it's truly a gre...
# 2          7  (Music: "The Sound of Silence," Simon & Garfun...
# 3         10  If you're here today — and I'm very happy that...
# 4          8  About 10 years ago, I took on the task to teac...
# 5         10  Thank you. I have to tell you I'm both challen...
# 6          7  On September 10, the morning of my seventh bir...
# 7          9  I'm going to present three projects in rapid f...
# 8         24  It's wonderful to be back. I love this wonderf...
# 9         10  I'm often asked, "What surprised you about the...
# 10        10  I'm going to take you on a journey very quickl...
# 11        10  I can't help but this wish: to think about whe...
# 12        10  I'm the luckiest guy in the world. I got to se...
# 13        23  I'm really excited to be here today. I'll show...
# 14        10  I've been at MIT for 44 years. I went to TED I...
# 15        23  (Music)(Music ends)(Applause)(Applause ends)Hi...
# 16        23  (Music)(Music ends)(Applause)Thank you!(Applau...
# 17        10  In terms of invention, I'd like to tell you th...
# 18        10  My name is Lovegrove. I only know nine Lovegro...
# 19         8  Charles Van Doren, who was later a senior edit...
# 20         8  I'm Rich Baraniuk and what I'd like to talk a ...
# 21         7  You know, when Chris first approached me to sp...
# 22        11  Over the past couple of days, as I've been pre...
# 23         8  I'd like to talk today about the two biggest s...
# 24        10  I bet you're worried.(Laughter)I was worried. ...
# 25        24  We've been told to go out on a limb and say so...
# 26        22  My title: "Queerer than we can suppose: the st...
# 27         8  You'll be happy to know that I'll be talking n...
# 28        22  I think I was supposed to talk about my new bo...
# 29        22  When you have 21 minutes to speak, two million...
# ...      ...                                                ...
# 2520      22                                                NaN
# 2521       8                                                NaN
# 2522       1                                                NaN
# 2523      10                                                NaN
# 2524      10                                                NaN
# 2525      10                                                NaN
# 2526       8                                                NaN
# 2527       8                                                NaN
# 2528       9                                                NaN
# 2529      10                                                NaN
# 2530      10                                                NaN
# 2531       8                                                NaN
# 2532      10                                                NaN
# 2533      10                                                NaN
# 2534       8                                                NaN
# 2535       3                                                NaN
# 2536      10                                                NaN
# 2537      10                                                NaN
# 2538      22                                                NaN
# 2539       8                                                NaN
# 2540       8                                                NaN
# 2541       8                                                NaN
# 2542       3                                                NaN
# 2543       8                                                NaN
# 2544       8                                                NaN
# 2545       8                                                NaN
# 2546       8                                                NaN
# 2547       8                                                NaN
# 2548      10                                                NaN
# 2549      10                                                NaN
#
# [2550 rows x 2 columns]
